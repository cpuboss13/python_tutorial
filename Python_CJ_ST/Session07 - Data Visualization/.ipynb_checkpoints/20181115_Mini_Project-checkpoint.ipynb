# %%
import math
import numpy as np
import pandas as pd

# %% [markdown]
# ### CSV 데이터 불러오기

# %%
selloutData = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %% [markdown]
# ### QTY=음수 구하기

# %%
answer1 = selloutData[(selloutData.QTY<0)]
answer1.head(2)
# Out:
#     REGIONID    PRODUCT  YEARWEEK  QTY
# 65       A02  PRODUCT16    201403 -1.0
# 338      A08  PRODUCT36    201402 -1.0

# %%
len(answer1)
# Out:
# 323

# %% [markdown]
# ### QTY=음수를 0으로 변환 후 QTY_NEW로

# %%
selloutData["QTY_NEW"] = np.where( selloutData["QTY"] < 0, 0, 
                                  selloutData["QTY"])
selloutData.head(1)
# Out:
#   REGIONID   PRODUCT  YEARWEEK   QTY  QTY_NEW
# 0      A60  PRODUCT4    201402  71.0     71.0

# %%
selloutData.head(1)
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# QTY_NEW     float64
# dtype: object

# %% [markdown]
# ### YEAR와 WEEK 분리

# %%
selloutData["YEAR"] = selloutData["YEARWEEK"].astype(str).str[0:4]
selloutData["WEEK"] = selloutData["YEARWEEK"].astype(str).str[4:]

# %%
selloutData.head(2)
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  QTY_NEW  YEAR WEEK
# 0      A60   PRODUCT4    201402     71.0     71.0  2014   02
# 1      A60  PRODUCT59    201402  22275.0  22275.0  2014   02

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# QTY_NEW     float64
# YEAR         object
# WEEK         object
# dtype: object

# %% [markdown]
# ### 53주차 날리기

# %%
cleanData = selloutData[selloutData.WEEK != "53"]
cleanData.head(10)
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  QTY_NEW  YEAR WEEK
# 0      A60   PRODUCT4    201402     71.0     71.0  2014   02
# 1      A60  PRODUCT59    201402  22275.0  22275.0  2014   02
# 2      A60  PRODUCT34    201402   4463.0   4463.0  2014   02
# 3      A60  PRODUCT47    201402      0.0      0.0  2014   02
# 4      A60  PRODUCT56    201402     23.0     23.0  2014   02
# 5      A60  PRODUCT57    201402     14.0     14.0  2014   02
# 6      A60  PRODUCT12    201402   1186.0   1186.0  2014   02
# 7      A60   PRODUCT1    201402      7.0      7.0  2014   02
# 8      A60  PRODUCT33    201402    101.0    101.0  2014   02
# 9      A60  PRODUCT62    201402    336.0    336.0  2014   02

# %%
len(cleanData)
# Out:
# 123864

# %%
len(selloutData)
# Out:
# 124658

# %%
len(selloutData)-len(cleanData)
# Out:
# 794

# %% [markdown]
# ### 컬럼명 소문자로 변경

# %%
cleanData.columns = cleanData.columns.str.lower()
sortedData = cleanData.sort_values(['regionid','product','yearweek'])
sortedData.reset_index(inplace=True, drop=True)

# %%
sortedData.head()
# Out:
#   regionid    product  yearweek    qty  qty_new  year week
# 0      A00  PRODUCT34    201401  661.0    661.0  2014   01
# 1      A00  PRODUCT34    201402  679.0    679.0  2014   02
# 2      A00  PRODUCT34    201403  578.0    578.0  2014   03
# 3      A00  PRODUCT34    201404  532.0    532.0  2014   04
# 4      A00  PRODUCT34    201405  516.0    516.0  2014   05

# %% [markdown]
# ### 이동평균 구하기

# %%
def sub_function(data):
    data["ma"] = data["qty_new"].rolling(window = 17, center = True, min_periods=1).mean()
    return data

# %%
maresult = sortedData.groupby(["regionid","product"]).apply(sub_function)
maresult.head()
# Out:
#   regionid    product  yearweek    qty  qty_new  year week          ma
# 0      A00  PRODUCT34    201401  661.0    661.0  2014   01  514.444444
# 1      A00  PRODUCT34    201402  679.0    679.0  2014   02  516.800000
# 2      A00  PRODUCT34    201403  578.0    578.0  2014   03  503.363636
# 3      A00  PRODUCT34    201404  532.0    532.0  2014   04  490.750000
# 4      A00  PRODUCT34    201405  516.0    516.0  2014   05  480.230769

# %% [markdown]
# ### 변동률 구하기

# %%
def sub_function2(data):
    data["std"] = data["ma"].rolling(window = 9, center = True, min_periods=1).std()
    return data

# %%
stdresult = maresult.groupby(["regionid","product"]).apply(sub_function2)
stdresult.head()
# Out:
#   regionid    product  yearweek    qty  qty_new  year week          ma  \
# 0      A00  PRODUCT34    201401  661.0    661.0  2014   01  514.444444
# 1      A00  PRODUCT34    201402  679.0    679.0  2014   02  516.800000
# 2      A00  PRODUCT34    201403  578.0    578.0  2014   03  503.363636
# 3      A00  PRODUCT34    201404  532.0    532.0  2014   04  490.750000
# 4      A00  PRODUCT34    201405  516.0    516.0  2014   05  480.230769
#
#          std
# 0  15.591135
# 1  19.362507
# 2  23.007444
# 3  26.416662
# 4  29.984975

# %% [markdown]
# ### UPPER BOUND / LOWER BOUND 구하기

# %%
stdresult["upper_bound"] = stdresult["ma"] + stdresult["std"]
stdresult["lower_bound"] = stdresult["ma"] - stdresult["std"]

# %%
stdresult.head()
# Out:
#   regionid    product  yearweek    qty  qty_new  year week          ma  \
# 0      A00  PRODUCT34    201401  661.0    661.0  2014   01  514.444444
# 1      A00  PRODUCT34    201402  679.0    679.0  2014   02  516.800000
# 2      A00  PRODUCT34    201403  578.0    578.0  2014   03  503.363636
# 3      A00  PRODUCT34    201404  532.0    532.0  2014   04  490.750000
# 4      A00  PRODUCT34    201405  516.0    516.0  2014   05  480.230769
#
#          std  upper_bound  lower_bound
# 0  15.591135   530.035579   498.853309
# 1  19.362507   536.162507   497.437493
# 2  23.007444   526.371081   480.356192
# 3  26.416662   517.166662   464.333338
# 4  29.984975   510.215744   450.245795

# %% [markdown]
# ### 정제된 판매량 구하기

# %%
stdresult["refined_qty"] = np.where(stdresult["qty_new"] > stdresult["upper_bound"], stdresult["upper_bound"],\
                           np.where(stdresult["qty_new"] < stdresult["lower_bound"], stdresult["lower_bound"],stdresult["qty_new"]))
stdresult.head()
# Out:
#   regionid    product  yearweek    qty  qty_new  year week          ma  \
# 0      A00  PRODUCT34    201401  661.0    661.0  2014   01  514.444444
# 1      A00  PRODUCT34    201402  679.0    679.0  2014   02  516.800000
# 2      A00  PRODUCT34    201403  578.0    578.0  2014   03  503.363636
# 3      A00  PRODUCT34    201404  532.0    532.0  2014   04  490.750000
# 4      A00  PRODUCT34    201405  516.0    516.0  2014   05  480.230769
#
#          std  upper_bound  lower_bound  refined_qty
# 0  15.591135   530.035579   498.853309   530.035579
# 1  19.362507   536.162507   497.437493   536.162507
# 2  23.007444   526.371081   480.356192   526.371081
# 3  26.416662   517.166662   464.333338   517.166662
# 4  29.984975   510.215744   450.245795   510.215744

# %% [markdown]
# ### 스무딩 처리

# %%
def sub_function3(data):
    data.reset_index(drop=True, inplace=True)    
    data["smooth"] = data["refined_qty"].rolling(window = 5, center = True, min_periods=1).mean()
    return data

smoothData = stdresult.groupby(["regionid","product"]).apply(sub_function3)  

smoothData.head()
# Out:
#                      regionid    product  yearweek    qty  qty_new  year week  \
# regionid product
# A00      PRODUCT34 0      A00  PRODUCT34    201401  661.0    661.0  2014   01
#                    1      A00  PRODUCT34    201402  679.0    679.0  2014   02
#                    2      A00  PRODUCT34    201403  578.0    578.0  2014   03
#                    3      A00  PRODUCT34    201404  532.0    532.0  2014   04
#                    4      A00  PRODUCT34    201405  516.0    516.0  2014   05
#
#                               ma        std  upper_bound  lower_bound  \
# regionid product
# A00      PRODUCT34 0  514.444444  15.591135   530.035579   498.853309
#                    1  516.800000  19.362507   536.162507   497.437493
#                    2  503.363636  23.007444   526.371081   480.356192
#                    3  490.750000  26.416662   517.166662   464.333338
#                    4  480.230769  29.984975   510.215744   450.245795
#
#                       refined_qty      smooth
# regionid product
# A00      PRODUCT34 0   530.035579  530.856389
#                    1   536.162507  527.433957
#                    2   526.371081  523.990314
#                    3   517.166662  504.548131
#                    4   510.215744  480.364578

# %% [markdown]
# ### 계절성 지수 1/2 구하기

# %%
smoothData["seasonality1"] = smoothData["qty_new"] / smoothData["smooth"]
smoothData["seasonality2"] = smoothData["refined_qty"] / smoothData["smooth"]
smoothData.head()
# Out:
#                      regionid    product  yearweek    qty  qty_new  year week  \
# regionid product
# A00      PRODUCT34 0      A00  PRODUCT34    201401  661.0    661.0  2014   01
#                    1      A00  PRODUCT34    201402  679.0    679.0  2014   02
#                    2      A00  PRODUCT34    201403  578.0    578.0  2014   03
#                    3      A00  PRODUCT34    201404  532.0    532.0  2014   04
#                    4      A00  PRODUCT34    201405  516.0    516.0  2014   05
#
#                               ma        std  upper_bound  lower_bound  \
# regionid product
# A00      PRODUCT34 0  514.444444  15.591135   530.035579   498.853309
#                    1  516.800000  19.362507   536.162507   497.437493
#                    2  503.363636  23.007444   526.371081   480.356192
#                    3  490.750000  26.416662   517.166662   464.333338
#                    4  480.230769  29.984975   510.215744   450.245795
#
#                       refined_qty      smooth  seasonality1  seasonality2
# regionid product
# A00      PRODUCT34 0   530.035579  530.856389      1.245158      0.998454
#                    1   536.162507  527.433957      1.287365      1.016549
#                    2   526.371081  523.990314      1.103074      1.004544
#                    3   517.166662  504.548131      1.054409      1.025010
#                    4   510.215744  480.364578      1.074184      1.062143

# %%
pwd
# Out:
# 'D:\\Python_CJ_Project\\Python_CJ_ST\\Session07 - Data Visualization'

# %% [markdown]
# ### CSV로 저장하기

# %%
smoothData.to_csv("../smoothData_result.csv")
