# %% [markdown]
# # Linear Regression Example

# %%
import numpy as np
import pandas as pd 

# 모델 라이브러리 선언
from sklearn import datasets, linear_model

# 모델 정확도 라이브러리 선언
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# 시각화 라이브러리 선언
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. 분석데이터 로딩

# %%
pwd
# Out:
# 'C:\\Users\\cj\\Python_CJ_ST_COPY\\Python_CJ_ST\\Session01 - Why Python for Data Analysis'

# %%
#CSV 파일을 읽어 DataFrame 변수에 저장하기
featuresData = pd.read_csv("../dataset./feature_regression_example.csv")

# %%
featuresData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %%
featuresData.head(2)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442

# %%
featuresData.corr()
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT
# YEARWEEK     1.000000  0.961051  0.213022  0.037392 -0.030681     0.300320
# YEAR         0.961051  1.000000 -0.065302 -0.048803  0.067443     0.208435
# WEEK         0.213022 -0.065302  1.000000  0.307541 -0.349205     0.347462
# QTY          0.037392 -0.048803  0.307541  1.000000 -0.544920     0.712772
# HCLUS       -0.030681  0.067443 -0.349205 -0.544920  1.000000    -0.552991
# PRO_PERCENT  0.300320  0.208435  0.347462  0.712772 -0.552991     1.000000

# %% [markdown]
# ### 2.데이터 형 변환

# %%
featuresData.dtypes
# Out:
# REGIONID         object
# PRODUCTGROUP     object
# PRODUCT          object
# ITEM             object
# YEARWEEK          int64
# YEAR              int64
# WEEK              int64
# QTY               int64
# HOLIDAY          object
# HCLUS             int64
# PROMOTION        object
# PRO_PERCENT     float64
# dtype: object

# %%
#형변환
featuresData[['WEEK','QTY','PRO_PERCENT']]=featuresData[['WEEK','QTY','PRO_PERCENT']].astype('float64')
featuresData.dtypes
# Out:
# REGIONID         object
# PRODUCTGROUP     object
# PRODUCT          object
# ITEM             object
# YEARWEEK          int64
# YEAR              int64
# WEEK            float64
# QTY             float64
# HOLIDAY          object
# HCLUS             int64
# PROMOTION        object
# PRO_PERCENT     float64
# dtype: object

# %% [markdown]
# ### 3. 문자데이터 코드변환(Vector연산)

# %%
#case when 
############################
def codeConversion(df):
    if df == "Y":
        return 1
    else:
        return 0

# %%
featuresData['PROMOTIONCODE'] = featuresData['PROMOTION'].apply(codeConversion)
featuresData.head(2)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015   1.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015   2.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE
# 0  1225.0       Y      1         Y     0.209442              1
# 1   968.0       N      4         Y     0.209442              1

# %%
featuresData['HOLIDAYCODE'] = featuresData['HOLIDAY'].apply(codeConversion)
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015   1.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015   2.0
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015   3.0
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015   4.0
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015   5.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1225.0       Y      1         Y     0.209442              1            1
# 1   968.0       N      4         Y     0.209442              1            0
# 2  1209.0       N      4         Y     0.208155              1            0
# 3  1810.0       Y      2         Y     0.208155              1            1
# 4  1773.0       N      4         Y     0.208155              1            0

# %%
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015   1.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015   2.0
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015   3.0
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015   4.0
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015   5.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1225.0       Y      1         Y     0.209442              1            1
# 1   968.0       N      4         Y     0.209442              1            0
# 2  1209.0       N      4         Y     0.208155              1            0
# 3  1810.0       Y      2         Y     0.208155              1            1
# 4  1773.0       N      4         Y     0.208155              1            0

# %%
featuresData.corr()
# Out:
#                YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT  \
# YEARWEEK       1.000000  0.961051  0.213022  0.037392 -0.030681     0.300320
# YEAR           0.961051  1.000000 -0.065302 -0.048803  0.067443     0.208435
# WEEK           0.213022 -0.065302  1.000000  0.307541 -0.349205     0.347462
# QTY            0.037392 -0.048803  0.307541  1.000000 -0.544920     0.712772
# HCLUS         -0.030681  0.067443 -0.349205 -0.544920  1.000000    -0.552991
# PRO_PERCENT    0.300320  0.208435  0.347462  0.712772 -0.552991     1.000000
# PROMOTIONCODE  0.108551  0.085606  0.089293  0.630081 -0.386926     0.903477
# HOLIDAYCODE    0.009395 -0.070803  0.284231  0.514813 -0.974902     0.496585
#
#                PROMOTIONCODE  HOLIDAYCODE
# YEARWEEK            0.108551     0.009395
# YEAR                0.085606    -0.070803
# WEEK                0.089293     0.284231
# QTY                 0.630081     0.514813
# HCLUS              -0.386926    -0.974902
# PRO_PERCENT         0.903477     0.496585
# PROMOTIONCODE       1.000000     0.378861
# HOLIDAYCODE         0.378861     1.000000

# %% [markdown]
# ### 4. 데이터 셋 분리

# %%
predictStd = 201630

# %%
#where between and (조건 절)
trainingData = featuresData.query('YEARWEEK <= @predictStd')
trainingData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015   1.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015   2.0
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015   3.0
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015   4.0
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015   5.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1225.0       Y      1         Y     0.209442              1            1
# 1   968.0       N      4         Y     0.209442              1            0
# 2  1209.0       N      4         Y     0.208155              1            0
# 3  1810.0       Y      2         Y     0.208155              1            1
# 4  1773.0       N      4         Y     0.208155              1            0

# %%
#where between and (조건 절)
testData = featuresData.query('YEARWEEK > @predictStd')
testData.head()
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 83  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016  31.0
# 84  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016  32.0
# 85  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016  33.0
# 86  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016  34.0
# 87  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016  35.0
#
#        QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 83  1522.0       N      4         Y     0.280258              1            0
# 84  2100.0       N      4         Y     0.280258              1            0
# 85    43.0       N      4         N     0.000000              0            0
# 86  1700.0       Y      1         Y     0.308584              1            1
# 87  1514.0       Y      1         Y     0.308584              1            1

# %%
trainingData_feature = trainingData[['WEEK','PRO_PERCENT','HOLIDAYCODE']]

# %%
trainingData_label = trainingData[['QTY']]

# %%
testData_feature = testData[['WEEK','PRO_PERCENT','HOLIDAYCODE']]

# %%
testData_label = testData[['QTY']]

# %%
# from sklearn import tree
#clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %% [markdown]
# ### 5. 모델선언 및 예측

# %% [markdown]
# ### 안녕하세요

# %%
#model_method= tree.DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=0)

# %%
# from sklearn import tree
#model_method = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
# from sklearn import tree
model_method = linear_model.LinearRegression()

# %%
### Extract Coefficient 머신러닝!!

# %%
model = model_method.fit(trainingData_feature, trainingData_label)

# %%
predict = model.predict(testData_feature)

# %%
predict
# Out:
# array([[1363.12337213],
#        [1367.51233386],
#        [ 301.07146112],
#        [1945.76874053],
#        [1950.15770226],
#        [1954.54666398],
#        [1497.68802819],
#        [1502.07698991],
#        [1398.23506593],
#        [1402.62402766],
#        [1868.2605869 ],
#        [1411.40195111],
#        [ 344.96107837],
#        [2422.58190441],
#        [2426.97086614],
#        [2431.35982787],
#        [2435.74878959],
#        [2440.13775132],
#        [1983.27911552],
#        [1722.01044627],
#        [1726.399408  ],
#        [2192.03596724],
#        [ 200.12534144],
#        [ 217.68118834]])

# %%
# 정답지
testData_label.head()
# Out:
#        QTY
# 83  1522.0
# 84  2100.0
# 85    43.0
# 86  1700.0
# 87  1514.0

# %% [markdown]
# ### 6. 데이터 정리

# %%
type(predict)
# Out:
# numpy.ndarray

# %%
predictData = pd.DataFrame(predict)

# %%
predictData
# Out:
#               0
# 0   1363.123372
# 1   1367.512334
# 2    301.071461
# 3   1945.768741
# 4   1950.157702
# 5   1954.546664
# 6   1497.688028
# 7   1502.076990
# 8   1398.235066
# 9   1402.624028
# 10  1868.260587
# 11  1411.401951
# 12   344.961078
# 13  2422.581904
# 14  2426.970866
# 15  2431.359828
# 16  2435.748790
# 17  2440.137751
# 18  1983.279116
# 19  1722.010446
# 20  1726.399408
# 21  2192.035967
# 22   200.125341
# 23   217.681188

# %%
predictData.head()
# Out:
#              0
# 0  1363.123372
# 1  1367.512334
# 2   301.071461
# 3  1945.768741
# 4  1950.157702

# %%
predictData.columns = ["PREDICT"]

# %%
testData
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 83   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016  31.0
# 84   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016  32.0
# 85   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016  33.0
# 86   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016  34.0
# 87   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016  35.0
# 88   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016  36.0
# 89   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016  37.0
# 90   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016  38.0
# 91   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016  39.0
# 92   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016  40.0
# 93   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016  41.0
# 94   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016  42.0
# 95   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016  43.0
# 96   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016  44.0
# 97   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016  45.0
# 98   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016  46.0
# 99   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016  47.0
# 100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016  48.0
# 101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016  49.0
# 102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016  50.0
# 103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016  51.0
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016  52.0
# 105  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201710  2017  10.0
# 106  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201714  2017  14.0
#
#         QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 83   1522.0       N      4         Y     0.280258              1            0
# 84   2100.0       N      4         Y     0.280258              1            0
# 85     43.0       N      4         N     0.000000              0            0
# 86   1700.0       Y      1         Y     0.308584              1            1
# 87   1514.0       Y      1         Y     0.308584              1            1
# 88   1501.0       Y      1         Y     0.308584              1            1
# 89   1491.0       N      4         Y     0.308584              1            0
# 90    806.0       N      4         Y     0.308584              1            0
# 91   2111.0       N      4         Y     0.280258              1            0
# 92   2400.0       N      4         Y     0.280258              1            0
# 93   2010.0       Y      2         Y     0.280258              1            1
# 94   1900.0       N      4         Y     0.280258              1            0
# 95    141.0       N      4         N     0.000000              0            0
# 96   1615.0       Y      0         Y     0.421888              1            1
# 97   1574.0       Y      0         Y     0.421888              1            1
# 98   1800.0       Y      0         Y     0.421888              1            1
# 99   2600.0       Y      0         Y     0.421888              1            1
# 100  2412.0       Y      0         Y     0.421888              1            1
# 101  1955.0       N      4         Y     0.421888              1            0
# 102  1800.0       N      4         Y     0.352361              1            0
# 103  1173.0       N      4         Y     0.352361              1            0
# 104   332.0       Y      1         Y     0.352361              1            1
# 105    14.0       N      4         N     0.000000              0            0
# 106     5.0       N      4         N     0.000000              0            0

# %%
testData.reset_index(drop=True, inplace=True)

# %%
testData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016  31.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016  32.0
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016  33.0
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016  34.0
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016  35.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1522.0       N      4         Y     0.280258              1            0
# 1  2100.0       N      4         Y     0.280258              1            0
# 2    43.0       N      4         N     0.000000              0            0
# 3  1700.0       Y      1         Y     0.308584              1            1
# 4  1514.0       Y      1         Y     0.308584              1            1

# %%
predictData.reset_index(drop=True, inplace=True)

# %%
#testData_feature.reset_index(drop=True, inplace=True)

# %%
#cncatenate labels to df as a new column / column binding
finalDf = pd.concat([testData, predictData], axis = 1)

# %%
finalDf.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016  31.0
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016  32.0
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016  33.0
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016  34.0
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016  35.0
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE  \
# 0  1522.0       N      4         Y     0.280258              1            0
# 1  2100.0       N      4         Y     0.280258              1            0
# 2    43.0       N      4         N     0.000000              0            0
# 3  1700.0       Y      1         Y     0.308584              1            1
# 4  1514.0       Y      1         Y     0.308584              1            1
#
#        PREDICT
# 0  1363.123372
# 1  1367.512334
# 2   301.071461
# 3  1945.768741
# 4  1950.157702

# %%
finalDf.to_csv("./dt_result_20181112_LinearRegression.csv")

# %%
pwd
# Out:
# 'C:\\Users\\cj\\Python_CJ_ST_COPY\\Python_CJ_ST\\Session01 - Why Python for Data Analysis'

# %% [markdown]
# ### 7. 정확도 측정

# %%
mean_absolute_error(finalDf['QTY'], finalDf['PREDICT'])
# Out:
# 455.62189421546094

# %%
mean_squared_error(finalDf['QTY'], finalDf['PREDICT'])
# Out:
# 376307.3344786445

# %%
r2_score(finalDf['QTY'], finalDf['PREDICT'])
# Out:
# 0.38670554032608817

# %%
finalDf.to_csv("./decisiontree_result_LinearRegression.csv")
