# %%
import pandas as pd
customerData = pd.read_csv("../dataset/customerData.csv")
customerData.head(2)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566    4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219    3642.44195    2          4.0    2.682023      Sleeping-dog

# %% [markdown]
# ### 실습 1

# %%
import pandas as pd
customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
customerData = pd.DataFrame(customerData)
answer1 = customerData.query('GENDER=="Male" & EMAIL > 0')
answer1.head()
# Out:
#      CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0         1503989    State2   2   Male    0        1      1         0
# 16        1154228    State2   2   Male    0        1      1         0
# 81         393246    State2   2   Male    0        1      1         1
# 206       2532568    State2   2   Male    1        1      1         0
# 216        487928    State2   2   Male    0        1      1         0
#
#      TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0           30300          0      30300          0              0           0
# 16          18200          0          0      18200              0           0
# 81          18200          0          0      18200              0           0
# 206         48000      48000          0          0              0           0
# 216         72300          0      27900      44400              0           0
#
#      CNT_VIST  GAP_VISIT
# 0           1          0
# ...

# %% [markdown]
# ### 실습2

# %%
import pandas as pd
productData = pd.read_csv("../dataset/kopo_product_volume.csv")
productData = pd.DataFrame(productData)
answer = productData.query('PRODUCTGROUP == "ST0002"  & VOLUME > 300000')
answer
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271
# 212      A01       ST0002    201549   669711
# 216      A01       ST0002    201547   378339
# 224      A01       ST0002    201548  1400339

# %% [markdown]
# ### 원하는 컬럼조회 실습

# %%
custom = pd.read_csv("../dataset/kopo_customerdata.csv")
custom = pd.DataFrame(custom)
answer = custom[['CUSTOMERCODE','STATENAME','TOTAL_AMOUNT']]
answer
# Out:
#         CUSTOMERCODE STATENAME  TOTAL_AMOUNT
# 0            1503989    State2         30300
# 1            1190338    State2         46500
# 2            1424715    State2         22700
# 3            2483305    State2         31400
# 4            1178802    State2         44900
# 5             859044    State2         38300
# 6             734198    State2         19900
# 7            1443485    State2         14800
# 8            2340520    State2         24400
# 9             697949    State2         30400
# 10            385031    State2         30300
# 11           1944258    State2         34300
# 12           2029521    State2         14900
# 13           1429192    State2         16300
# 14            892851    State2         25000
# 15           1554976    State2         27500
# 16           1154228    State2         18200
# 17            816582    State2         40200
# 18            675948    State2         74600
# 19            965940    State2         42700
# ...

# %% [markdown]
# ### 인덱스 활용하여 조회 실습

# %%
custom1 = pd.read_csv("../dataset/kopo_customerdata.csv")
custom1 = pd.DataFrame(custom1)
answer2 = custom1.iloc[0:5,[1,3]]
answer2
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %%
custom1 = pd.read_csv("../dataset/kopo_customerdata.csv")
custom1 = pd.DataFrame(custom1)
answer2 = custom1.loc[0:5,["STATENAME","GENDER"]]
answer2
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male
# 5    State2    Male

# %% [markdown]
# ### 이상데이터 정제하기 실습

# %%
import pandas as pd
import numpy as np
customerData = pd.read_csv("../dataset/customerdata.csv")
customerData["PRODUCTAGE_NEW"] = np.where(customerData["PRODUCTAGE"]<1, 1,\
                                 np.where(customerData["PRODUCTAGE"]<2, 2,\
                                 np.where(customerData["PRODUCTAGE"]<3, 3,\
                                 5)))
customerData.head(5)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3
# 2               5
# 3               1
# 4               3

# %%
customerData.head(2)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566    4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219    3642.44195    2          4.0    2.682023      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3

# %% [markdown]
# ### 데이터 정렬하기 실습

# %%
customerData.sort_values(["CUSTID","AVERAGEPRICE"], ascending=[True,False])
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# ### 데이터 요약분석하기 실습

# %%
# EMI별 MAX값을 구하세요
maxValue = customerData.groupby(['EMI'], as_index=True).max()
print(maxValue)
# Out:
#      CUSTID  AVERAGEPRICE  DEVICECOUNT  PRODUCTAGE      CUSTTYPE  \
# EMI
# 1    Y12458   3419.462596          6.3    2.994395  Sleeping-dog
# 2    Z19835   4166.533130          6.9    3.483573  Sleeping-dog
# 3    Z13534   4296.873743          6.9    2.055707    Early-bird
#
#      PRODUCTAGE_NEW
# EMI
# 1                 3
# 2                 5
# 3                 3

# %%
# 기본통계치 구하기
stdValue = customerData.groupby(['EMI'], as_index=True).describe()
stdValue
# Out:
#     AVERAGEPRICE                                                     \
#            count         mean         std          min          25%
# EMI
# 1           11.0  3119.031810  301.047916  2390.083736  2978.220215
# 2          120.0  3441.429664  349.691674  2411.008838  3231.429242
# 3           19.0  3559.487188  454.411870  2811.265932  3219.363531
#
#                                            DEVICECOUNT           ...   \
#              50%          75%          max       count      mean ...
# EMI                                                              ...
# 1    3159.839204  3363.814315  3419.462596        11.0  4.163636 ...
# 2    3418.480121  3656.799297  4166.533130       120.0  5.375833 ...
# 3    3592.353540  3867.447366  4296.873743        19.0  6.463158 ...
#
#     PRODUCTAGE           PRODUCTAGE_NEW                                     \
#            75%       max          count      mean       std  min  25%  50%
# EMI
# ...

# %%
# 이동평균 구간정의
order = 5
import math
suborder = math.floor(order/2)
suborder

# 연산
customerData["TEST"] = customerData["PRODUCTAGE"].rolling(window=5, center=False).mean()
customerData
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# ### 데이터 합치기 실습

# %%
regionMasterData = pd.read_csv("../dataset/kopo_region_mst.csv")
selectExample = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv", encoding = 'ms949')
regionMasterData.head(2)
# Out:
#   REGIONID REGIONNAME
# 0      A00     AFRICA
# 1      A01    AMERICA

# %%
selectExample.head(2)
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0

# %%
# 데이터 조인
mergeResult = pd.merge(selectExample, regionMasterData,\
              left_on="REGIONID", right_on="REGIONID", how="left")\
              [["REGIONID","REGIONNAME","PRODUCT","YEARWEEK","QTY"]]
mergeResult.head()
# Out:
#   REGIONID REGIONNAME    PRODUCT  YEARWEEK      QTY
# 0      A60       THAI   PRODUCT4    201402     71.0
# 1      A60       THAI  PRODUCT59    201402  22275.0
# 2      A60       THAI  PRODUCT34    201402   4463.0
# 3      A60       THAI  PRODUCT47    201402      0.0
# 4      A60       THAI  PRODUCT56    201402     23.0

# %%
# INNER JOIN시
len(mergeResult)
# Out:
# 124344

# %%
# LEFT JOIN시
len(mergeResult)
# Out:
# 124658

# %%
# REGIONNAME이 Null값이 데이터 구하기
mergeResult[mergeResult["REGIONNAME"].isnull()]
# Out:
#        REGIONID REGIONNAME    PRODUCT  YEARWEEK      QTY
# 176         A77        NaN  PRODUCT12    201404   2628.0
# 177         A77        NaN   PRODUCT1    201404   1623.0
# 269         A77        NaN  PRODUCT12    201401   3821.0
# 270         A77        NaN   PRODUCT1    201401   3580.0
# 1728        A77        NaN  PRODUCT12    201402   2466.0
# 1729        A77        NaN   PRODUCT1    201402   2465.0
# 2711        A77        NaN  PRODUCT12    201405   1442.0
# 2712        A77        NaN   PRODUCT1    201405   1482.0
# 3096        A77        NaN  PRODUCT12    201403   2401.0
# 3097        A77        NaN   PRODUCT1    201403   2205.0
# 4105        A77        NaN  PRODUCT12    201406   3794.0
# 4106        A77        NaN   PRODUCT1    201406   4735.0
# 6259        A77        NaN  PRODUCT12    201407   2409.0
# 6260        A77        NaN   PRODUCT1    201407   3633.0
# 6653        A77        NaN  PRODUCT12    201409   2587.0
# ...

# %% [markdown]
# ### 그룹바이 심화 실습 (일반 접근방법)

# %%
# 이동평균 계산 적용
selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")
selloutData.head()
# Out:
#   REGIONID PRODUCTGROUP  YEARWEEK  VOLUME
# 0      A01       ST0001    201415  810144
# 1      A01       ST0002    201415  128999
# 2      A01       ST0001    201418  671464
# 3      A01       ST0002    201418  134467
# 4      A01       ST0001    201413  470040

# %%
selloutData.columns = selloutData.columns.str.lower()

# %%
sortedData = selloutData.sort_values(["regionid","productgroup","yearweek"])
sortedData.reset_index(inplace=True, drop=True)
sortedData.head()
# Out:
#   regionid productgroup  yearweek  volume
# 0      A01       ST0001    201401  513598
# 1      A01       ST0001    201402  438251
# 2      A01       ST0001    201403  420290
# 3      A01       ST0001    201404  458431
# 4      A01       ST0001    201405  482381

# %%
sortedData["ma"] = sortedData["volume"].rolling(window=17, center=False, min_periods=1).mean()
sortedData.head()
# Out:
#   regionid productgroup  yearweek  volume             ma
# 0      A01       ST0001    201401  513598  513598.000000
# 1      A01       ST0001    201402  438251  475924.500000
# 2      A01       ST0001    201403  420290  457379.666667
# 3      A01       ST0001    201404  458431  457642.500000
# 4      A01       ST0001    201405  482381  462590.200000

# %% [markdown]
# ### 그룹바이 심화 실습 (고급 접근방법)

# %%
def sub_function(data):
    data["ma"] = data["volume"].rolling(window = 5, center = True, min_periods = 1).mean()
    return data

# %%
import pandas as pd

selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")
selloutData
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 0        A01       ST0001    201415   810144
# 1        A01       ST0002    201415   128999
# 2        A01       ST0001    201418   671464
# 3        A01       ST0002    201418   134467
# 4        A01       ST0001    201413   470040
# 5        A01       ST0002    201413   140297
# 6        A01       ST0001    201411   524787
# 7        A01       ST0002    201411   145509
# 8        A01       ST0001    201416   764927
# 9        A01       ST0002    201416   140313
# 10       A01       ST0001    201419   682757
# 11       A01       ST0002    201419   128668
# 12       A01       ST0001    201414   428195
# 13       A01       ST0002    201414   137488
# 14       A01       ST0001    201412   486509
# 15       A01       ST0001    201417   697502
# 16       A01       ST0002    201417   127163
# 17       A01       ST0001    201407   620392
# 18       A01       ST0002    201407   146476
# 19       A01       ST0001    201410   511679
# ...

# %%
selloutData.columns = selloutData.columns.str.lower()

# %%
sortedData = selloutData.sort_values(["regionid","productgroup","yearweek"])
sortedData.reset_index(inplace=True, drop=True)
sortedData.head()
# Out:
#   regionid productgroup  yearweek  volume
# 0      A01       ST0001    201401  513598
# 1      A01       ST0001    201402  438251
# 2      A01       ST0001    201403  420290
# 3      A01       ST0001    201404  458431
# 4      A01       ST0001    201405  482381

# %%
finalGroupResult = sortedData.groupby(["regionid","productgroup"]).apply(sub_function)
finalGroupResult.head()
# Out:
#   regionid productgroup  yearweek  volume             ma
# 0      A01       ST0001    201401  513598  457379.666667
# 1      A01       ST0001    201402  438251  457642.500000
# 2      A01       ST0001    201403  420290  462590.200000
# 3      A01       ST0001    201404  458431  473953.000000
# 4      A01       ST0001    201405  482381  510381.200000

# %%
pwd
# Out:
# 'D:\\Python_CJ_Project\\Python_CJ_ST\\Session03 - Learning basic grammar and data import'
